# %%
import pandas as pd
dijkstra = pd.read_csv('1bag_time_dijkstra_entries.csv', sep=',').values[:, 1]
ppo = pd.read_csv('1bag_time_ppo_entries.csv', sep=',').values[:, 1]
dqn = pd.read_csv('1bag_time_dqn_entries.csv', sep=',').values[:, 1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-cafacfaa06cd> in <module>
#       2 dijkstra = pd.read_csv('1bag_time_dijkstra_entries.csv', sep=',').values[:, 1]
#       3 ppo = pd.read_csv('1bag_time_ppo_entries.csv', sep=',').values[:, 1]
# ----> 4 dqn = pd.read_csv('1bag_time_dqn_entries.csv', sep=',').values[:, 1]
#
# ...

# %%
ppo.mean() / dijkstra.mean(), dqn.mean() / dijkstra.mean()
# Out:
# (1.0, 1.0288659533691649)

# %%
from matplotlib import pyplot as plt

n = 150
plt.figure(figsize=(12, 6))
plot(dijkstra_energy, 'dijkstra')
plot(ppo_energy, 'ppo')
plt.grid(True)
plt.xlabel('time')
plt.ylabel('bag time')
plt.legend()
plt.show()

# %%
dijkstra_energy = pd.read_csv('1energy_consumption_dijkstra_entries.csv', sep=',')
ppo_energy = pd.read_csv('1energy_consumption_ppo_entries.csv', sep=',')

# %%
dijkstra_energy.sum(), ppo_energy.sum()
# Out:
# (time     3.204208e+07
#  value    1.056882e+08
#  dtype: float64,
#  time     3.196204e+07
#  value    1.101921e+08
#  dtype: float64)

# %%
def plot(energy, label):
    energy['time'] //= n
    energy = energy.groupby('time').agg('mean')
    energy.index *= n
    plt.plot(energy.index, energy['value'], label=label)

# %%
from matplotlib import pyplot as plt

n = 150
plt.figure(figsize=(12, 6))
plot(dijkstra_energy, 'dijkstra')
plot(ppo_energy, 'ppo')
plt.grid(True)
plt.xlabel('time')
plt.ylabel('energy')
plt.legend()
plt.show()
