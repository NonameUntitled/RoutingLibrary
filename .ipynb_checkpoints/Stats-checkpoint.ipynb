# %%
import pandas as pd
dijkstra = pd.read_csv('results/1bag_time_dijkstra_entries.csv', sep=',')
ppo = pd.read_csv('results/1bag_time_ppo_entries.csv', sep=',')
dqn = pd.read_csv('results/1bag_time_dqn_entries.csv', sep=',')

# %%
ppo.values[:, 1].mean() / dijkstra.values[:, 1].mean(), dqn.values[:, 1].mean() / dijkstra.values[:, 1].mean()
# Out:
# (1.0679339005557467, 1.0663699404908276)

# %%
from matplotlib import pyplot as plt

n = 50
plt.figure(figsize=(12, 6))
plot(dijkstra, 'dijkstra')
plot(dqn, 'dqn')
plot(ppo, 'ppo')
plt.grid(True)
plt.xlabel('time')
plt.ylabel('bag time')
plt.legend()
plt.show()

# %%
dijkstra_energy = pd.read_csv('results/1energy_consumption_dijkstra_entries.csv', sep=',')
ppo_energy = pd.read_csv('results/1energy_consumption_ppo_entries.csv', sep=',')
dqn_energy = pd.read_csv('results/1energy_consumption_dqn_entries.csv', sep=',')
time = dijkstra_energy.loc[int(len(dijkstra_energy) * 0.2), 'time']
dijkstra_energy = dijkstra_energy[dijkstra_energy['time'] > time]
ppo_energy = ppo_energy[ppo_energy['time'] > time]
dqn_energy = dqn_energy[dqn_energy['time'] > time]

# %%
ppo_energy.values[:, 1].sum() / dijkstra_energy.values[:, 1].sum(), dqn_energy.values[:, 1].sum() / dijkstra_energy.values[:, 1].sum()
# Out:
# (0.9456759427663027, 0.9737147681730086)

# %%
def plot(energy, label):
    energy = energy.copy()
    energy['time'] //= n
    energy = energy.groupby('time').agg('mean')
    energy.index *= n
    plt.plot(energy.index, energy['value'], label=label)

# %%
from matplotlib import pyplot as plt

n = 30
plt.figure(figsize=(12, 6))
plot(dijkstra_energy, 'dijkstra')
plot(dqn_energy, 'dqn')
plot(ppo_energy, 'ppo')
plt.grid(True)
plt.xlabel('time')
plt.ylabel('energy')
plt.legend()
plt.show()

# %%
import json
import numpy as np

class Source:
    def __init__(self, source_idx, upstream_idx):
        self.source_idx = source_idx
        self.upstream_idx = upstream_idx
    
    def to_json(self):
        return f'"{self.source_idx}": {{ "upstream_conv": {self.upstream_idx} }}'
    
class Sink:
    def __init__(self, sink_idx):
        self.sink_idx = sink_idx
    
    def to_json(self):
        return f'{self.sink_idx}'

class Diverter:
    def __init__(self, diverter_idx, conveyor_idx, pos, upstream_idx):
        self.diverter_idx = diverter_idx
        self.conveyor_idx = conveyor_idx
        self.pos = pos
        self.upstream_idx = upstream_idx
        
    def to_json(self):
        return f'"{self.diverter_idx}": {{ "conveyor": {self.conveyor_idx}, "pos": {self.pos}, "upstream_conv": {self.upstream_idx} }}'
    
class Conveyor:
    def __init__(self, conveyor_idx, length, quality, upstream_type, upstream_idx, upstream_pos = None):
        self.conveyor_idx = conveyor_idx
        self.length = length
        self.quality = quality
        self.upstream_type = upstream_type
        self.upstream_idx = upstream_idx
        self.upstream_pos = upstream_pos
            
    def to_json(self):
        pos = f', "pos": {self.upstream_pos}' if self.upstream_pos else ''
        return f'"{self.conveyor_idx}": {{ "length": {self.length}, "quality": {self.quality}, "upstream": {{ "type": "{self.upstream_type}", "id": {self.upstream_idx}{pos} }} }}'

def to_jsons(items):
    return [item.to_json() for item in items]
    
def json_topology(sources, sinks, diverters, conveyors):
    sources = to_jsons(sources)
    sinks = to_jsons(sinks)
    diverters = to_jsons(diverters)
    conveyors = to_jsons(conveyors)
    topology_str = f'{{ "topology": {{ "type": "oriented", "sources": {{ {", ".join(sources)} }}, "sinks": [{", ".join(sinks)}], "diverters": {{ {", ".join(diverters)} }}, "conveyors": {{ {", ".join(conveyors)} }} }} }}'
    return json.dumps(json.loads(topology_str), indent=2)

def random_quality():
    return np.random.choice([1.0, 1.5, 2.5])

# %%
topology = json_topology(
    [Source(0, 0)],
    [Sink(0), Sink(1)],
    [Diverter(0, 0, 20, 1), Diverter(1, 1, 15, 2)],
    [Conveyor(0, 100, 1, 'sink', 0), Conveyor(1, 30, 5, 'sink', 1), Conveyor(2, 10, 5, 'conveyor', 0, 80)]
)
print(topology)
# Out:
# {
#   "topology": {
#     "type": "oriented",
#     "sources": {
#       "0": {
#         "upstream_conv": 0
#       }
#     },
#     "sinks": [
#       0,
#       1
#     ],
#     "diverters": {
#       "0": {
#         "conveyor": 0,
#         "pos": 20,
#         "upstream_conv": 1
#       },
#       "1": {
#         "conveyor": 1,
#         "pos": 15,
#         "upstream_conv": 2
#       }
#     },
#     "conveyors": {
#       "0": {
#         "length": 100,
#         "quality": 1,
#         "upstream": {
#           "type": "sink",
#           "id": 0
#         }
#       },
#       "1": {
#         "length": 30,
#         "quality": 5,
#         "upstream": {
#           "type": "sink",
#           "id": 1
#         }
#       },
#       "2": {
#         "length": 10,
#         "quality": 5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 0,
#           "pos": 80
#         }
#       }
#     }
#   }
# }

# %%
n = 4
a = 10
l = 15
sources = [Source(i, i) for i in range(n)]
sinks = [Sink(i) for i in range(n)]
diverters = []
for i in range(n - 1):
    for j in range(n):
        diverters.append(Diverter(n + i * n * 2 + j, i, a + 4 * j * a, 2 * n + i * n * 2 + j))
for i in range(1, n):
    for j in range(n):
        diverters.append(Diverter(n + i * n * 2 + j + n, i, 3 * a + 4 * j * a, 3 * n + i * n * 2 + j))
for i in range(n):
    diverters.append(Diverter(i, i, 4 * a * (n + 2), i + n))
conveyors = []
for i in range(n - 1):
    for j in range(n):
        conveyors.append(Conveyor(2 * n + i * n * 2 + j, l + np.random.rand() * 10, random_quality(), 'conveyor', i + 1, 2 * a + 4 * j * a))
for i in range(1, n):
    for j in range(n):
        conveyors.append(Conveyor(3 * n + i * n * 2 + j, l + np.random.rand() * 10, random_quality(), 'conveyor', i - 1, 4 * a + 4 * j * a))
for i in range(n):
    conveyors.append(Conveyor(i, 4 * a * (n + 5), random_quality(), 'sink', i))
    conveyors.append(Conveyor(i + n, 5 * l, random_quality(), 'conveyor', (i + 1) % n, 4 * a * (n + 2) - 2 * a))
topology = json_topology(sources, sinks, diverters, conveyors)
print(topology)
# Out:
# {
#   "topology": {
#     "type": "oriented",
#     "sources": {
#       "0": {
#         "upstream_conv": 0
#       },
#       "1": {
#         "upstream_conv": 1
#       },
#       "2": {
#         "upstream_conv": 2
#       }
#     },
#     "sinks": [
#       0,
#       1,
#       2
#     ],
#     "diverters": {
#       "3": {
#         "conveyor": 0,
#         "pos": 10,
#         "upstream_conv": 6
#       },
#       "4": {
#         "conveyor": 0,
#         "pos": 50,
#         "upstream_conv": 7
#       },
#       "5": {
#         "conveyor": 0,
#         "pos": 90,
#         "upstream_conv": 8
#       },
#       "9": {
#         "conveyor": 1,
#         "pos": 10,
#         "upstream_conv": 12
#       },
#       "10": {
#         "conveyor": 1,
#         "pos": 50,
#         "upstream_conv": 13
#       },
#       "11": {
#         "conveyor": 1,
#         "pos": 90,
#         "upstream_conv": 14
#       },
#       "12": {
#         "conveyor": 1,
#         "pos": 30,
#         "upstream_conv": 15
#       },
#       "13": {
#         "conveyor": 1,
#         "pos": 70,
#         "upstream_conv": 16
#       },
#       "14": {
#         "conveyor": 1,
#         "pos": 110,
#         "upstream_conv": 17
#       },
#       "18": {
#         "conveyor": 2,
#         "pos": 30,
#         "upstream_conv": 21
#       },
#       "19": {
#         "conveyor": 2,
#         "pos": 70,
#         "upstream_conv": 22
#       },
#       "20": {
#         "conveyor": 2,
#         "pos": 110,
#         "upstream_conv": 23
#       },
#       "0": {
#         "conveyor": 0,
#         "pos": 200,
#         "upstream_conv": 3
#       },
#       "1": {
#         "conveyor": 1,
#         "pos": 200,
#         "upstream_conv": 4
#       },
#       "2": {
#         "conveyor": 2,
#         "pos": 200,
#         "upstream_conv": 5
#       }
#     },
#     "conveyors": {
#       "6": {
#         "length": 24.357916295782815,
#         "quality": 1.0,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 20
#         }
#       },
#       "7": {
#         "length": 16.05749036661102,
#         "quality": 1.0,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 60
#         }
#       },
#       "8": {
#         "length": 18.30729181691347,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 100
#         }
#       },
#       "12": {
#         "length": 15.190448874344895,
#         "quality": 2.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 2,
#           "pos": 20
#         }
#       },
#       "13": {
#         "length": 18.544469983135542,
#         "quality": 2.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 2,
#           "pos": 60
#         }
#       },
#       "14": {
#         "length": 19.756573214675548,
#         "quality": 1.0,
#         "upstream": {
#           "type": "conveyor",
#           "id": 2,
#           "pos": 100
#         }
#       },
#       "15": {
#         "length": 20.69825013307743,
#         "quality": 2.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 0,
#           "pos": 40
#         }
#       },
#       "16": {
#         "length": 15.492884293181284,
#         "quality": 1.0,
#         "upstream": {
#           "type": "conveyor",
#           "id": 0,
#           "pos": 80
#         }
#       },
#       "17": {
#         "length": 21.608581235000322,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 0,
#           "pos": 120
#         }
#       },
#       "21": {
#         "length": 21.380721152681573,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 40
#         }
#       },
#       "22": {
#         "length": 19.99028756973552,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 80
#         }
#       },
#       "23": {
#         "length": 19.640348661261253,
#         "quality": 2.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 120
#         }
#       },
#       "0": {
#         "length": 320,
#         "quality": 2.5,
#         "upstream": {
#           "type": "sink",
#           "id": 0
#         }
#       },
#       "3": {
#         "length": 75,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 1,
#           "pos": 180
#         }
#       },
#       "1": {
#         "length": 320,
#         "quality": 1.5,
#         "upstream": {
#           "type": "sink",
#           "id": 1
#         }
#       },
#       "4": {
#         "length": 75,
#         "quality": 1.5,
#         "upstream": {
#           "type": "conveyor",
#           "id": 2,
#           "pos": 180
#         }
#       },
#       "2": {
#         "length": 320,
#         "quality": 2.5,
#         "upstream": {
#           "type": "sink",
#           "id": 2
#         }
#       },
#       "5": {
#         "length": 75,
#         "quality": 1.0,
#         "upstream": {
#           "type": "conveyor",
#           "id": 0,
#           "pos": 180
#         }
#       }
#     }
#   }
# }
